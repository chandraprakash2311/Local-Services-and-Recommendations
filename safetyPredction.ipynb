# %%
positive_safety=[
    "The area was very well-lit, which made me feel safe at night.",
    "There were visible security measures, including cameras and patrols.",
    "The neighborhood had a friendly and safe vibe.",
    "I felt comfortable walking around, even late in the evening.",
    "The streets were clean and well-maintained, adding to the sense of safety.",
    "There were lots of people around, which made it feel secure.",
    "The public transportation stops were in safe, well-lit areas.",
    "I saw plenty of police patrols, which was reassuring.",
    "There were lots of families and kids around, making it feel safe.",
    "The area was quiet and peaceful, even during busy times.",
    "There were clear signs and directions, making it easy to navigate safely.",
    "I noticed emergency call boxes and helpful security features throughout the area.",
    "The local businesses added to the feeling of safety.",
    "There was a strong sense of community, which made me feel secure.",
    "The parks and public spaces were well-kept and felt safe.",
    "The area had a low crime rate, according to local reports.",
    "The streets were well-lit, even in the early morning hours.",
    "There were security guards present in key locations.",
    "I saw plenty of neighborhood watch signs and felt reassured.",
    "The area was known for being safe, and it lived up to its reputation.",
    "There were many people out walking, which made it feel secure.",
    "The neighborhood had a welcoming atmosphere and felt safe.",
    "I felt safe parking my car in the well-lit, secure parking areas.",
    "The area was busy but orderly, contributing to a sense of safety.",
    "There were clear crosswalks and traffic lights for pedestrian safety.",
    "The surroundings were well-organized and had good safety measures.",
    "I felt comfortable and safe walking my dog around the neighborhood.",
    "The local community center provided good safety information.",
    "The area had a calm, peaceful vibe with friendly residents.",
    "There were safe pathways and walkways throughout the area.",
    "The streets had good visibility and open spaces.",
    "The neighborhood was quiet, with no signs of trouble.",
    "The local parks were clean and well-patrolled.",
    "The area felt secure, with no signs of crime or vandalism.",
    "The streets were easy to navigate and felt very safe.",
    "There were plenty of well-lit areas, even in the alleys.",
    "I noticed a lot of local residents keeping an eye on things.",
    "The area had a good reputation for safety, which was evident.",
    "There were safe and well-maintained bike paths.",
    "I saw several security personnel, which was reassuring.",
    "The area was clean and felt very safe to walk around.",
    "There were no signs of suspicious activity or crime.",
    "The neighborhood had a strong community feel.",
    "I felt very secure walking around, even at night.",
    "The public spaces were well-maintained and felt safe.",
    "The local shops and businesses added to the area's safety.",
    "There were plenty of well-lit parking spots.",
    "The area was very family-friendly and felt secure.",
    "I felt comfortable exploring the neighborhood on my own.",
    "The streets were well-marked and easy to navigate safely.",
    "The neighborhood was very quiet and felt safe all the time.",
    "The area was known for its low crime rate, and it shows.",
    "There were always friendly people around, making it feel secure.",
    "The local parks had plenty of lighting and felt very safe.",
    "Walking paths were well-maintained and felt secure.",
    "The community was tight-knit, and everyone looked out for each other.",
    "Public areas were clean and well-monitored by security.",
    "There was a good mix of residential and commercial areas, adding to the safety.",
    "The area was well-regarded by locals for being very safe.",
    "Street lighting was excellent, making it easy to feel safe at night.",
    "Local law enforcement was visible and friendly.",
    "The surrounding businesses maintained a clean and safe environment.",
    "The area was very pedestrian-friendly and felt secure.",
    "There were plenty of families and kids playing outside, indicating safety.",
    "I noticed many safety features like crosswalks and stop signs.",
    "There were well-kept gardens and parks adding to the safety feel.",
    "The local community often held events, which enhanced the safe atmosphere.",
    "The area had excellent public facilities that were well-maintained.",
    "The neighborhood had a peaceful and safe vibe day and night.",
    "There were plenty of outdoor spaces that felt very secure.",
    "Emergency services were close by and easily accessible.",
    "The streets were busy with friendly locals, adding to the safety.",
    "The area was highly recommended by friends for its safety.",
    "Even late at night, the area felt safe and welcoming.",
    "The neighborhood had a strong reputation for being a safe place.",
    "Local cafes and shops were always clean and felt safe.",
    "Public transportation was reliable and felt secure.",
    "The community was proactive about maintaining safety standards.",
    "There were always helpful people around if you needed assistance.",
    "The area had clear and visible safety signs and information.",
    "The environment was peaceful, with no signs of trouble.",
    "The local neighborhood watch was active and visible.",
    "It felt safe to walk or jog around, even in the early morning.",
    "The community vibe was very welcoming and secure.",
    "There were dedicated bike lanes that felt safe to use.",
    "The streets were well-organized with clear safety measures.",
    "The local parks had regular patrols, adding to the safety.",
    "Public events were well-organized and felt very secure.",
    "The area was quiet and safe, perfect for families.",
    "Even during busy times, the area felt orderly and safe.",
    "The local schools had excellent safety records.",
    "There were many open spaces and parks that were well-patrolled.",
    "The community was known for being friendly and safe.",
    "There were many security features like cameras and patrols.",
    "The area was well-lit and felt very safe at all hours.",
    "I always felt safe walking my dog in the neighborhood.",
    "There were frequent community events that enhanced the sense of safety.",
    "The area had a very low crime rate, which was reassuring.",
    "The local shops and cafes felt secure and welcoming.",
    "The neighborhood was very peaceful, even on weekends."

]

# %%
negative_safety=[
    "The neighborhood felt unsafe and poorly lit at night.",
    "There were not enough security cameras around.",
    "I saw some shady characters loitering in the area.",
    "The streets were dirty and poorly maintained.",
    "There was a lot of noise and commotion, especially at night.",
    "I didn't see any police presence in the vicinity.",
    "The area seemed neglected and run-down.",
    "There were many dark alleys that felt unsafe to walk through.",
    "The public transportation stops were in poorly lit areas.",
    "The area had a high crime rate according to local news.",
    "I felt uneasy walking around the neighborhood, even during the day.",
    "There were reports of frequent thefts and break-ins in the area.",
    "The community didn't seem friendly or welcoming.",
    "There were no emergency call boxes in sight.",
    "I wouldn't feel comfortable walking here alone at night.",
    "The local parks were poorly maintained and felt unsafe.",
    "There were frequent reports of vandalism and graffiti.",
    "The area was overcrowded and felt chaotic.",
    "I saw some suspicious activities while walking around.",
    "The streets were poorly lit and felt very unsafe at night.",
    "There were many abandoned buildings and empty lots.",
    "The area seemed unsafe, especially for families and kids.",
    "There were no visible security measures or patrols.",
    "The neighborhood had a rough reputation according to locals.",
    "I didn't feel safe parking my car in the area.",
    "There were a lot of loud and rowdy gatherings.",
    "I noticed broken streetlights and dark corners.",
    "The area was notorious for muggings and assaults.",
    "The public spaces were dirty and poorly monitored.",
    "The local community didn't seem to care about safety.",
    "There were no clear signs or directions for safe pathways.",
    "I saw many people arguing and causing disturbances.",
    "The area had a lot of transient and homeless individuals.",
    "There was a lot of litter and broken glass on the sidewalks.",
    "I heard about frequent fights and disturbances in the area.",
    "The local businesses didn't seem to prioritize safety.",
    "The streets were narrow and difficult to navigate safely.",
    "The area had a lot of traffic and speeding cars.",
    "There were no bike paths or safe walking routes.",
    "The neighborhood felt isolated and unwelcoming.",
    "The local parks were empty and felt eerie.",
    "There was a lot of construction and unsafe areas.",
    "The area was poorly planned with no clear safety measures.",
    "I didn't feel comfortable leaving my belongings unattended.",
    "There were frequent power outages affecting streetlights.",
    "The area had a lot of stray animals roaming around.",
    "There were no visible neighborhood watch signs.",
    "I saw many broken and abandoned vehicles.",
    "The area felt deserted and unsafe, especially at night.",
    "There were a lot of unsavory characters hanging around.",
    "The neighborhood was poorly lit, making it feel unsafe.",
    "I heard about several recent crimes in the area.",
    "The sidewalks were broken and hazardous to walk on.",
    "There was a lot of loitering near public spaces.",
    "I saw several arguments and disturbances while visiting.",
    "The area felt very neglected and unsafe.",
    "There were not enough streetlights, especially in key areas.",
    "The streets were dirty and had a lot of litter.",
    "The local parks were in disrepair and felt unsafe.",
    "I noticed a lot of broken windows and vandalism.",
    "There were too many dark and isolated areas.",
    "The area had a reputation for being unsafe, which it lived up to.",
    "I didn't feel comfortable walking around, even during the day.",
    "There were frequent reports of drug activity.",
    "The area felt very chaotic and unorganized.",
    "I saw a lot of people acting suspiciously.",
    "There was no visible police presence at all.",
    "The streets were often empty and felt deserted.",
    "There were many loud and unruly gatherings.",
    "The neighborhood had a high turnover of residents.",
    "There was a lot of graffiti and vandalism.",
    "The area was very noisy, even late at night.",
    "I felt uneasy due to the lack of security measures.",
    "There were frequent incidents of theft and burglary.",
    "The public spaces were poorly lit and felt unsafe.",
    "I saw many broken streetlights that hadn't been fixed.",
    "The area had a lot of abandoned and empty buildings.",
    "There were frequent reports of violent crimes.",
    "The local businesses didn't seem to care about safety.",
    "I didn't see any security guards or patrols.",
    "There were no clear safety signs or guidelines.",
    "The area was very crowded and felt overwhelming.",
    "There were a lot of homeless people and panhandlers.",
    "I felt very uneasy walking through the neighborhood.",
    "The area had a lot of loud and disruptive noise.",
    "There were frequent power outages, affecting streetlights.",
    "The streets were narrow and difficult to navigate.",
    "I saw many people arguing and causing disturbances.",
    "There were too many dark corners and alleyways.",
    "The neighborhood felt very run-down and unsafe.",
    "I heard sirens frequently, indicating a lot of emergencies.",
    "There were no visible efforts to improve safety.",
    "The area was very poorly maintained overall.",
    "I felt like I had to constantly watch my surroundings.",
    "There were a lot of stray animals causing disturbances.",
    "The local parks were often empty and felt creepy.",
    "There were frequent car break-ins reported.",
    "The area felt isolated and disconnected from the city."

]

# %%
safety_reviews = positive_safety + negative_safety
safety_labels = [1] * len(positive_safety) + [0] * len(negative_safety)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, Trainer, TrainingArguments
from sklearn.metrics import accuracy_score
import torch

# Tokenization
tokenizer_safety = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')

# Splitting data
train_texts, test_texts, train_labels, test_labels = train_test_split(safety_reviews, safety_labels, test_size=0.2, random_state=42)

# Define dataset class
class ReviewDataset(torch.utils.data.Dataset):
    def __init__(self, texts, labels, tokenizer, max_length):
        self.encodings = tokenizer_safety(texts, truncation=True, padding=True, max_length=max_length)
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

train_dataset = ReviewDataset(train_texts, train_labels, tokenizer_safety, max_length=128)
test_dataset = ReviewDataset(test_texts, test_labels, tokenizer_safety, max_length=128)

# Model initialization
model_safety = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=2)

# Training arguments
training_args = TrainingArguments(
    output_dir='./results_saftey',
    per_device_train_batch_size=4,
    num_train_epochs=1,  # Train for 10 epochs
    logging_dir='./logs_safety',
)

# Trainer
trainer = Trainer(
    model=model_safety,
    args=training_args,
    train_dataset=train_dataset,
)

# Train the model
trainer.train()

# Evaluate the model
predictions = trainer.predict(test_dataset)
y_pred = predictions.predictions.argmax(-1)
accuracy = accuracy_score(test_labels, y_pred)
print("Accuracy:", accuracy)
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#   0%|          | 0/40 [00:00<?, ?it/s]
# {'train_runtime': 74.1542, 'train_samples_per_second': 2.131, 'train_steps_per_second': 0.539, 'train_loss': 0.524845027923584, 'epoch': 1.0}
#   0%|          | 0/5 [00:00<?, ?it/s]
# Accuracy: 0.975

# %%
model_safety.save_pretrained('./safetyresults')
tokenizer_safety.save_pretrained('./safetyresults')
# Out:
# ('./safetyresults\\tokenizer_config.json',
#  './safetyresults\\special_tokens_map.json',
#  './safetyresults\\vocab.txt',
#  './safetyresults\\added_tokens.json')
